# %%
import torch
from torch.utils.data import DataLoader
from util import *
from IPython.core.interactiveshell import InteractiveShell
import matplotlib.pyplot as plt
InteractiveShell.ast_node_interactivity = 'all'

# %%
dataset = EnvelopDataset(dir='./img/', shrink=10)
loader = DataLoader(dataset=dataset, batch_size=1)

# %%
net = ConvNet()
net.load_state_dict(torch.load('./cnn_norm.pt'))
# Out:
# <All keys matched successfully>

# %%
for im, path in loader:
    y = net(im.view([-1, *im.shape[2:]])).argmax(dim=1).view([-1, 6])
    for i in range(6):
        n = plt.subplot(1, 6, i+1)
        n = plt.imshow(im[0][i].squeeze(),cmap='gray')
    plt.show()
    y, path
# Out:
# (tensor([[1, 2, 5, 4, 1, 6]]), ('./img/0.png',))
# (tensor([[2, 3, 4, 5, 6, 6]]), ('./img/1.png',))
# (tensor([[3, 4, 7, 1, 7, 8]]), ('./img/2.png',))
# (tensor([[4, 5, 8, 2, 8, 7]]), ('./img/3.png',))
# (tensor([[5, 6, 2, 6, 7, 0]]), ('./img/4.png',))
# (tensor([[0, 7, 5, 7, 0, 1]]), ('./img/5.png',))
# (tensor([[7, 5, 7, 0, 1, 2]]), ('./img/6.png',))
# (tensor([[8, 9, 0, 1, 2, 3]]), ('./img/7.png',))
# (tensor([[7, 6, 4, 2, 3, 4]]), ('./img/8.png',))
# (tensor([[0, 7, 6, 3, 2, 5]]), ('./img/9.png',))
